# %%
# ✅ Sentiment Analysis with Early Stopping + Model Saving (Google Colab Ready)

import numpy as np
import tensorflow as tf
from tensorflow.keras.datasets import imdb
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense, Dropout, Bidirectional
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
import pickle
import os

# -------------------------------
# 1. Load Dataset
# -------------------------------
vocab_size = 10000  # top 10k words
maxlen = 200       # max review length

(x_train, y_train), (x_test, y_test) = imdb.load_data(num_words=vocab_size)
x_train = pad_sequences(x_train, maxlen=maxlen)
x_test = pad_sequences(x_test, maxlen=maxlen)

# -------------------------------
# 2. Build Model
# -------------------------------
model = Sequential([
    Embedding(vocab_size, 128, input_length=maxlen),
    Bidirectional(LSTM(128, return_sequences=True)),
    Dropout(0.3),
    Bidirectional(LSTM(64)),
    Dropout(0.3),
    Dense(64, activation="relu"),
    Dropout(0.3),
    Dense(1, activation="sigmoid")
])

model.compile(
    loss="binary_crossentropy",
    optimizer="adam",
    metrics=["accuracy"]
)

model.summary()

# -------------------------------
# 3. Callbacks (Early Stopping + Save Best Model)
# -------------------------------
os.makedirs("saved_model", exist_ok=True)

early_stop = EarlyStopping(monitor="val_loss", patience=3, restore_best_weights=True)
checkpoint = ModelCheckpoint("saved_model/best_model.h5", monitor="val_accuracy",
                             save_best_only=True, verbose=1)

# -------------------------------
# 4. Train
# -------------------------------
history = model.fit(
    x_train, y_train,
    epochs=10,
    batch_size=128,
    validation_split=0.2,
    callbacks=[early_stop, checkpoint],
    verbose=1
)

# -------------------------------
# 5. Evaluate
# -------------------------------
loss, acc = model.evaluate(x_test, y_test, verbose=0)
print(f"✅ Test Accuracy: {acc*100:.2f}%")

# -------------------------------
# 6. Save Final Model + Tokenizer
# -------------------------------
model.save("saved_model/final_model.h5")
print("📂 Final model saved at saved_model/final_model.h5")

# Save word index for decoding reviews
word_index = imdb.get_word_index()
with open("saved_model/word_index.pkl", "wb") as f:
    pickle.dump(word_index, f)

print("📂 Word index (Tokenizer equivalent) saved successfully!")
# Out:
# ...
# 17464789/17464789 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/embedding.py:97: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)           │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional (Bidirectional)   │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ ?                      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import pickle
import os

# 1. Save trained model
model.save("sentiment_model.h5")
print("📂 Model saved as sentiment_model.h5")

# 2. Save tokenizer (needed for future predictions)
with open("tokenizer.pkl", "wb") as f:
    pickle.dump(tokenizer, f)
print("📂 Tokenizer saved as tokenizer.pkl")

# 3. (Optional) Save word index separately
with open("word_index.pkl", "wb") as f:
    pickle.dump(word_index, f)
print("📂 Word index saved as word_index.pkl")

# If using LabelEncoder for >2 classes:
# with open("label_encoder.pkl", "wb") as f:
#     pickle.dump(label_encoder, f)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3306924175.py in <cell line: 0>()
#       3
#       4 # 1. Save trained model
# ----> 5 model.save("sentiment_model.h5")
#       6 print("📂 Model saved as sentiment_model.h5")
#       7
#
# NameError: name 'model' is not defined

# %%
import pickle
import tensorflow as tf
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing.sequence import pad_sequences

# Load model
model = load_model("sentiment_model.h5")

# Load tokenizer
with open("tokenizer.pkl", "rb") as f:
    tokenizer = pickle.load(f)

# Predict function
def predict_sentiment(text, model, tokenizer, maxlen=200):
    seq = tokenizer.texts_to_sequences([text])
    padded = pad_sequences(seq, maxlen=maxlen)
    pred = model.predict(padded)[0][0]
    sentiment = "😊 Positive" if pred >= 0.5 else "😡 Negative"
    return sentiment, float(pred)

# Example
text = "This movie was amazing!"
sentiment, confidence = predict_sentiment(text, model, tokenizer)
print(f"Text: {text}")
print(f"Sentiment: {sentiment} | Confidence: {confidence:.2f}")

# %%
import os

print("Contents of current directory:")
print(os.listdir())

print("\nContents of saved_model directory:")
try:
    print(os.listdir("saved_model"))
except FileNotFoundError:
    print("The 'saved_model' directory was not found.")
# Out:
# Contents of current directory:
# ['.config', 'sample_data']
#
# Contents of saved_model directory:
# The 'saved_model' directory was not found.

# %%
import os

try:
    os.makedirs("saved_model", exist_ok=True)
    print("✅ 'saved_model' directory created successfully.")
except Exception as e:
    print(f"❌ Error creating directory: {e}")

print("\nContents of current directory after attempted creation:")
print(os.listdir())
# Out:
# ✅ 'saved_model' directory created successfully.
#
# Contents of current directory after attempted creation:
# ['.config', 'saved_model', 'sample_data']
